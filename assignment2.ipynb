# %% [markdown]
# # Abalone dataset

# %%
import pandas
import matplotlib
abalone_df = pandas.read_csv("abalone.data", names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight',
                                  'Rings'])
abalone_df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# - How many columns are there?<br>
# 9
# - How many rows are there?<br>
# 4176
# - Are the columns numerical, categorical, or both?<br>
# The first column is categorical and the rest are numerical.
# - Are there columns that provide no information? Just constant values for all observations.<br>
# No, all columns return a false value from nunique() == 1.

# %%
abalone_df.nunique() == 1
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %% [markdown]
# - For each categorical columns compute the mode.<br>

# %%
abalone_df.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %% [markdown]
# - For each numerical column compute the mean (average), max, and min values.<br>

# %%
abalone_df.mean()
# Out:
# Length            0.523992
# Diameter          0.407881
# Height            0.139516
# Whole weight      0.828742
# Shucked weight    0.359367
# Viscera weight    0.180594
# Shell weight      0.238831
# Rings             9.933684
# dtype: float64

# %%
abalone_df.min()
# Out:
# Sex                    F
# Length             0.075
# Diameter           0.055
# Height                 0
# Whole weight       0.002
# Shucked weight     0.001
# Viscera weight    0.0005
# Shell weight      0.0015
# Rings                  1
# dtype: object

# %%
abalone_df.max()
# Out:
# Sex                    M
# Length             0.815
# Diameter            0.65
# Height              1.13
# Whole weight      2.8255
# Shucked weight     1.488
# Viscera weight      0.76
# Shell weight       1.005
# Rings                 29
# dtype: object

# %% [markdown]
# <br>
# - Plot histograms for numerical columns.<br>

# %%
matplotlib.rcParams.update({'font.size': 40})
abalone_df.hist(figsize=(50, 40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbd2468490>,
# ...
#       dtype=object)

# %% [markdown]
# <br>
# - Plot bar plots for categorical columns.<br>

# %%
matplotlib.rcParams.update({'font.size': 100})
abalone_df['Sex'].value_counts().plot(kind='bar', figsize=(50, 40), rot=0).set(xlabel="Sex", ylabel="Occurrences", title="Male, Female, Infant Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'Sex'),
#  Text(0.5, 1.0, 'Male, Female, Infant Frequency (categorical)')]

# %% [markdown]
# <br>
# # Adult dataset

# %%
adult_df = pandas.read_csv("adult.data", names=['age', 'workclass' ,'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship',
                                  'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'above-below-50k'])

# %%
adult_df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# -   How many columns are there? <br>
#     14
# -     How many rows are there? <br>
#     32561
# -     Are the columns numerical, categorical, or both? <br>
#     The columns are both numerical and categorical.
#
# -     Are there columns that provide no information? Just constant values for all observations. <br>
#     No, all columns return a false value from nunique() == 1.

# %%
adult_df.nunique() == 1
# Out:
# age                False
# workclass          False
# fnlwgt             False
# education          False
# education-num      False
# marital-status     False
# occupation         False
# relationship       False
# race               False
# sex                False
# capital-gain       False
# capital-loss       False
# hours-per-week     False
# native-country     False
# above-below-50k    False
# dtype: bool

# %% [markdown]
# - For each categorical columns compute the mode.<br>

# %%
adult_df.mode()
# Out:
#     age workclass  fnlwgt education  education-num       marital-status  \
# 0  36.0   Private  123011   HS-grad            9.0   Married-civ-spouse
# 1   NaN       NaN  164190       NaN            NaN                  NaN
# 2   NaN       NaN  203488       NaN            NaN                  NaN
#
#         occupation relationship    race    sex  capital-gain  capital-loss  \
# 0   Prof-specialty      Husband   White   Male           0.0           0.0
# 1              NaN          NaN     NaN    NaN           NaN           NaN
# 2              NaN          NaN     NaN    NaN           NaN           NaN
#
#    hours-per-week  native-country above-below-50k
# 0            40.0   United-States           <=50K
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN

# %% [markdown]
# - For each numerical column compute the mean (average), max, and min values.<br>

# %%
adult_df.mean()
# Out:
# age                   38.581647
# fnlwgt            189778.366512
# education-num         10.080679
# capital-gain        1077.648844
# capital-loss          87.303830
# hours-per-week        40.437456
# dtype: float64

# %%
adult_df.min()
# Out:
# age                                 17
# workclass                            ?
# fnlwgt                           12285
# education                         10th
# education-num                        1
# marital-status                Divorced
# occupation                           ?
# relationship                   Husband
# race                Amer-Indian-Eskimo
# sex                             Female
# capital-gain                         0
# capital-loss                         0
# hours-per-week                       1
# native-country                       ?
# above-below-50k                  <=50K
# dtype: object

# %%
adult_df.max()
# Out:
# age                               90
# workclass                Without-pay
# fnlwgt                       1484705
# education               Some-college
# education-num                     16
# marital-status               Widowed
# occupation          Transport-moving
# relationship                    Wife
# race                           White
# sex                             Male
# capital-gain                   99999
# capital-loss                    4356
# hours-per-week                    99
# native-country            Yugoslavia
# above-below-50k                 >50K
# dtype: object

# %% [markdown]
# - Plot histograms for numerical columns. <br>

# %%
matplotlib.rcParams.update({'font.size': 30})
adult_df.hist(figsize=(50, 40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfce0390>,
# ...
#       dtype=object)

# %% [markdown]
# - Plot bar plots for categorical columns.<br>

# %%
matplotlib.rcParams.update({'font.size': 40})
adult_df['workclass'].value_counts().plot(kind='bar', figsize=(50, 40), rot=0).set(xlabel="workclass", ylabel="Occurrences", title="Workclass Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'workclass'),
#  Text(0.5, 1.0, 'Workclass Frequency (categorical)')]

# %%
adult_df['native-country'].value_counts().plot(kind='bar', figsize=(50, 40)).set(xlabel="native-country", ylabel="Occurrences", title="native-country Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'native-country'),
#  Text(0.5, 1.0, 'native-country Frequency (categorical)')]

# %%
adult_df['education'].value_counts().plot(kind='bar', figsize=(50, 40)).set(xlabel="education", ylabel="Occurrences", title="education Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'education'),
#  Text(0.5, 1.0, 'education Frequency (categorical)')]

# %%
adult_df['marital-status'].value_counts().plot(kind='bar', figsize=(50, 40)).set(xlabel="marital-status", ylabel="Occurrences", title="marital-status Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'marital-status'),
#  Text(0.5, 1.0, 'marital-status Frequency (categorical)')]

# %%
adult_df['race'].value_counts().plot(kind='bar', figsize=(50, 40), rot=0).set(xlabel="race", ylabel="Occurrences", title="race Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'race'),
#  Text(0.5, 1.0, 'race Frequency (categorical)')]

# %%
adult_df['occupation'].value_counts().plot(kind='bar', figsize=(50, 40)).set(xlabel="occupation", ylabel="Occurrences", title="occupation Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'occupation'),
#  Text(0.5, 1.0, 'occupation Frequency (categorical)')]

# %%
adult_df['relationship'].value_counts().plot(kind='bar', figsize=(50, 40), rot=0).set(xlabel="relationship", ylabel="Occurrences", title="relationship Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'relationship'),
#  Text(0.5, 1.0, 'relationship Frequency (categorical)')]

# %% [markdown]
# <br>
# # Report
