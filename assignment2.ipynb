# %%
import pandas
import matplotlib
abalone_df = pandas.read_csv("abalone.data", names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight',
                                  'Rings'])
abalone_df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
abalone_df.nunique() == 1
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %% [markdown]
# - For each categorical columns compute the mode.<br>

# %%
abalone_df.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %% [markdown]
# - For each numerical column compute the mean (average), max, and min values.<br>

# %%
abalone_df.mean()
# Out:
# Length            0.523992
# Diameter          0.407881
# Height            0.139516
# Whole weight      0.828742
# Shucked weight    0.359367
# Viscera weight    0.180594
# Shell weight      0.238831
# Rings             9.933684
# dtype: float64

# %%
abalone_df.min()
# Out:
# Sex                    F
# Length             0.075
# Diameter           0.055
# Height                 0
# Whole weight       0.002
# Shucked weight     0.001
# Viscera weight    0.0005
# Shell weight      0.0015
# Rings                  1
# dtype: object

# %%
abalone_df.max()
# Out:
# Sex                    M
# Length             0.815
# Diameter            0.65
# Height              1.13
# Whole weight      2.8255
# Shucked weight     1.488
# Viscera weight      0.76
# Shell weight       1.005
# Rings                 29
# dtype: object

# %% [markdown]
# <br>
# - Plot histograms for numerical columns.<br>

# %%
matplotlib.rcParams.update({'font.size': 40})
abalone_df.hist(figsize=(50, 40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfbe1310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfb7fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfafb790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfb3af90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfac67d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfa6efd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfa2d810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcfa5ef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7efbcf9ebb90>]],
#       dtype=object)

# %% [markdown]
# <br>
# - Plot bar plots for categorical columns.<br>

# %%
matplotlib.rcParams.update({'font.size': 100})
abalone_df['Sex'].value_counts().plot(kind='bar', figsize=(50, 40), rot=0).set(xlabel="Sex", ylabel="Occurrences", title="Male, Female, Infant Frequency (categorical)")
# Out:
# [Text(0, 0.5, 'Occurrences'),
#  Text(0.5, 0, 'Sex'),
#  Text(0.5, 1.0, 'Male, Female, Infant Frequency (categorical)')]
